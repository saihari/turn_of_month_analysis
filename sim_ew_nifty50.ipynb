# %% [markdown]
# # Simulation of Turn of Month Strategy Based on Nifty 50 Equal Weight Portfolio

# %%
import vectorbt as vbt
import pandas as pd
import numpy as np
from numba import njit
from vectorbt.portfolio import nb
from vectorbt.portfolio.enums import Direction, NoOrder, SizeType


vbt.settings.portfolio["size_granularity"] = 1

# %%
# Reading the Data

base_path = "./data/simulation_input/nifty50/"
documentation_path = "./documentation/nifty50_ew_"

TurnOfMonthEntry = pd.read_csv(base_path + "master_TurnOfMonthEntry.csv")
TurnOfMonthExits = pd.read_csv(base_path + "master_TurnOfMonthExits.csv")
open_price = pd.read_csv(base_path + "master_open_price.csv")
close_price = pd.read_csv(base_path + "master_close_price.csv")

# %% [markdown]
# Set the index as Date and ensure that the entries and exits, are of data type bool and all the dates are of datetime64[ns, UTC+05:30].

# %%
TurnOfMonthEntry.Date = pd.to_datetime(TurnOfMonthEntry.loc[:, "Date"])
TurnOfMonthExits.Date = pd.to_datetime(TurnOfMonthExits.loc[:, "Date"])
open_price.Date = pd.to_datetime(open_price.loc[:, "Date"])
close_price.Date = pd.to_datetime(close_price.loc[:, "Date"])

TurnOfMonthEntry = TurnOfMonthEntry.set_index("Date")
TurnOfMonthExits = TurnOfMonthExits.set_index("Date")
open_price = open_price.set_index("Date")
close_price = close_price.set_index("Date")

for symbol in TurnOfMonthEntry.columns:
    TurnOfMonthEntry[symbol] = TurnOfMonthEntry[symbol].astype(bool)



for symbol in TurnOfMonthExits.columns:
    TurnOfMonthExits[symbol] = TurnOfMonthExits[symbol].astype(bool)

# %% [markdown]
# ## Simulation logic:
#
#     Buy at open on the last trading day of the month.
#     Sell at close on the third trading day of the next month.
#
# Since it is an equal weight simulation and there are 50 companies on the index at any given point of time.
#
# The weight of each company in the portfolio would be 2%.
#
# Also, initial cash is 5,00,000 INR.

# %%
@njit
def order_func_nb(c, entries, exits, size, open_price):

    # Select info related to this order
    entry_now = nb.get_elem_nb(c, entries)
    exit_now = nb.get_elem_nb(c, exits)
    size_now = nb.get_elem_nb(c, size)
    close_price = nb.get_elem_nb(c, c.close)
    open_price = nb.get_elem_nb(c, open_price)

    if entry_now:
        if c.position_now == 0:

            return nb.order_nb(
                size=size_now,
                price=open_price,
                direction=Direction.LongOnly,
                size_type=SizeType.TargetPercent,
                size_granularity= 1,
                min_size=1,
            )

    elif exit_now:
        if c.position_now > 0:
            return nb.order_nb(
                size=-c.position_now,
                price=close_price,
                direction=Direction.LongOnly,
                size_type=SizeType.TargetPercent,
                size_granularity=1,
                min_size=1,
            )

    return NoOrder


def simulate(open_price, close_price, entries, exits, size=0.02, group_by = False, cash_sharing = False, init_cash = 10000):

    return vbt.Portfolio.from_order_func(
        close_price,
        order_func_nb,
        vbt.Rep("entries"),
        vbt.Rep("exits"),
        vbt.Rep("size"),
        vbt.Rep("open_price"),
        init_cash=init_cash,
        cash_sharing=cash_sharing,
        group_by=group_by,
        broadcast_named_args=dict(  # broadcast against each other
            entries=entries, exits=exits, size=size, open_price=open_price
        ),
    )

# %% [markdown]
# ## Simulation

# %%
pf = simulate(
    open_price=open_price,
    close_price=close_price,
    entries=TurnOfMonthEntry[open_price.columns],
    exits=TurnOfMonthExits[open_price.columns],
    size=0.02,
    group_by=True,
    cash_sharing=True,
    init_cash=500000,
)

# %%
print("Total Returns: ", str(pf.total_return() * 100) + "%")
print("Total Annualized Return: ", str(pf.annualized_return(freq="d") * 100) + "%")
print("Total Annualized Volatility: ", str(pf.annualized_volatility(freq="d") * 100) + "%")
# Out:
# Total Returns:  331.70459073031276%
# Total Annualized Return:  15.211770961004923%
# Total Annualized Volatility:  8.950263020179841%

# %% [markdown]
# Monthly Returns

# %%
pf.qs.plot_monthly_heatmap()

# %% [markdown]
# Yearly Returns

# %%
temp = pd.DataFrame(pf.daily_returns()).reset_index()
temp.loc[:,"Year"] = temp.Date.dt.year
temp.fillna(0, inplace=True)
temp.groupby(by="Year").group.sum() * 100
# Out:
# c:\Users\saiha\anaconda3\envs\qfin\lib\site-packages\vectorbt\generic\accessors.py:578: FutureWarning: The 'axis' keyword in Series.resample is deprecated and will be removed in a future version.
#   resampled = self.obj.resample(freq, axis=0, **kwargs)
# Year
# 2009    20.750783
# 2010    18.232730
# 2011     6.135349
# 2012    15.746290
# 2013     4.893497
# 2014     6.599893
# 2015    12.468335
# 2016     8.777881
# 2017     8.416599
# 2018    -2.820527
# 2019    -3.833330
# 2020    10.222205
# 2021    17.975504
# 2022    13.526509
# 2023     7.272173
# 2024     6.042228
# Name: group, dtype: float64

# %%
pf.plot_value().write_image(engine="orca", file= documentation_path + "value.png")
pf.plot_value()
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '79c2ac17-4179-4a83-8fae-9278d207100c',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([500000., 500000., 500000., ..., 500000., 500000., 500000.])},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(0, 128, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '2cadb059-266f-4e2e-a204-b33e60a55356',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 500000.        ,  500000.        ,  500000.        , ...,
#                           2158522.95365156, 2158522.95365156, 2158522.95365156])},
#              {'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '2a99db57-f868-4fdd-a697-b1f9d1cffffb',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([500000., 500000., 500000., ..., 500000., 500000., 500000.])},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ead84206-b264-4020-80e6-b4dd029e5b06',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([500000., 500000., 500000., ..., 500000., 500000., 500000.])},
#              {'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '55ff9db5-c0b2-43b9-a6cb-4cb7785d7204',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 500000.        ,  500000.        ,  500000.        , ...,
#                           2158522.95365156, 2158522.95365156, 2158522.95365156])},
#              {'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'f1f271b2-3030-4792-9ad7-4f5c341edb90',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([500000., 500000., 500000., ..., 500000., 500000., 500000.])}],
#     'layout': {'height': 350,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.02,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 500000.0,
#                            'y1': 500000.0,
#                            'yref': 'y'}],
#                'template': '...',
#                'width': 700}
# })

# %%
pf.plot_drawdowns().write_image(engine="orca", file=documentation_path + "drawdowns.png")
pf.plot_drawdowns()
# Out:
# FigureWidget({
#     'data': [{'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '24abca90-2072-4a01-a238-ad6b945507d3',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 500000.        ,  500000.        ,  500000.        , ...,
#                           2158522.95365156, 2158522.95365156, 2158522.95365156])},
#              {'customdata': array([[  0],
#                                    [ 17],
#                                    [ 34],
#                                    [ 59],
#                                    [112]]),
#               'hovertemplate': 'Drawdown Id: %{customdata[0]}<br>Peak Timestamp: %{x}<br>Peak Value: %{y}',
#               'marker': {'color': '#4285F4',
#                          'line': {'color': 'rgb(11,84,205)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': 'Peak',
#               'type': 'scatter',
#               'uid': '4f738934-63ac-40cc-a1e8-9952f0684e60',
#               'x': array([datetime.datetime(2009, 2, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2010, 4, 23, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2011, 9, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2013, 2, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2017, 11, 3, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 509113.57786856,  678446.87588791,  788099.22692484,  932869.66185396,
#                           1382022.48510058])},
#              {'customdata': array([['0', '-0.0624319674238422', '26'],
#                                    ['17', '-0.060445164819607586', '28'],
#                                    ['34', '-0.0710621966936132', '40'],
#                                    ['59', '-0.05502166849147212', '146'],
#                                    ['112', '-0.12974377299647535', '610']], dtype=object),
#               'hovertemplate': ('Drawdown Id: %{customdata[0]}<' ... '<br>Duration: %{customdata[2]}'),
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': 'Valley',
#               'type': 'scatter',
#               'uid': '7cb9e0cb-eb08-4f0e-beb8-0fad20665f23',
#               'x': array([datetime.datetime(2009, 3, 13, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2010, 6, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2011, 11, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2013, 9, 4, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2020, 5, 6, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 477328.61556004,  637438.04265352,  732095.16464702,  881541.61657368,
#                           1202713.67351766])},
#              {'customdata': array([['0', '0.10186643159882498', '15'],
#                                    ['17', '0.0645119498110218', '86'],
#                                    ['34', '0.08098990716867804', '42'],
#                                    ['59', '0.06338751529931315', '58'],
#                                    ['112', '0.15337652164475737', '147']], dtype=object),
#               'hovertemplate': ('Drawdown Id: %{customdata[0]}<' ... '<br>Duration: %{customdata[2]}'),
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': 'Recovery/Peak',
#               'type': 'scatter',
#               'uid': '2085345e-9305-4df4-b2bc-1b83be6854ef',
#               'x': array([datetime.datetime(2009, 4, 6, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2010, 10, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2012, 1, 4, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2013, 12, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2020, 12, 3, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 525952.37832714,  678560.41366882,  791387.48407042,  937420.34928123,
#                           1387181.71329639])}],
#     'layout': {'height': 350,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.02,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2009-02-02 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2009-03-13 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2010-04-23 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2010-06-02 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2011-09-02 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2011-11-02 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2013-02-01 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2013-09-04 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2017-11-03 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2020-05-06 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2009-03-13 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2009-04-06 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2010-06-02 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2010-10-01 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2011-11-02 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2012-01-04 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2013-09-04 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2013-12-02 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2020-05-06 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2020-12-03 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'}],
#                'template': '...',
#                'width': 700}
# })

# %%
pf.plot_underwater().write_image(engine="orca", file=documentation_path + "underwater.png")
pf.plot_underwater()
# Out:
# FigureWidget({
#     'data': [{'fill': 'tozeroy',
#               'fillcolor': 'rgba(220,57,18,0.3000)',
#               'line': {'color': '#dc3912'},
#               'name': 'Drawdown',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7b1621bf-d398-4b2d-a7b4-9724f995ba39',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 0.       ,  0.       ,  0.       , ..., -0.0003204, -0.0003204,
#                           -0.0003204])}],
#     'layout': {'height': 350,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.02,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y'}],
#                'template': '...',
#                'width': 700,
#                'yaxis': {'tickformat': '%'}}
# })

# %% [markdown]
# Return Stats

# %%
pf.returns_stats(settings=dict(freq="d", risk_free=0.000192))
# Out:
# c:\Users\saiha\anaconda3\envs\qfin\lib\site-packages\vectorbt\returns\accessors.py:902: UserWarning:
#
# Changing the frequency will create a copy of this object. Consider setting it upon object creation to re-use existing cache.
# Start                        2009-01-01 00:00:00+05:30
# End                          2024-04-30 00:00:00+05:30
# Period                              3770 days 00:00:00
# Total Return [%]                            331.704591
# Benchmark Return [%]                       3111.285356
# Annualized Return [%]                        15.211771
# Annualized Volatility [%]                     8.950263
# Max Drawdown [%]                             12.974377
# Max Drawdown Duration                756 days 00:00:00
# Sharpe Ratio                                  0.843983
# Calmar Ratio                                  1.172447
# Omega Ratio                                   1.265292
# Sortino Ratio                                  2.67749
# Skew                                          1.163041
# Kurtosis                                     26.930253
# Tail Ratio                                     2.84957
# Common Sense Ratio                             3.28304
# Value at Risk                                -0.002409
# Alpha                                         0.041355
# Beta                                          0.115651
# Name: group, dtype: object

# %%
pf.stats(settings=dict(freq="d", risk_free=0.000192))
# Out:
# c:\Users\saiha\anaconda3\envs\qfin\lib\site-packages\vectorbt\generic\stats_builder.py:262: UserWarning:
#
# Changing the frequency will create a copy of this object. Consider setting it upon object creation to re-use existing cache.
# Start                         2009-01-01 00:00:00+05:30
# End                           2024-04-30 00:00:00+05:30
# Period                               3770 days 00:00:00
# Start Value                                    500000.0
# End Value                                2158522.953652
# Total Return [%]                             331.704591
# Benchmark Return [%]                        3111.285356
# Max Gross Exposure [%]                        99.999559
# Total Fees Paid                                     0.0
# Max Drawdown [%]                              12.974377
# Max Drawdown Duration                 756 days 00:00:00
# Total Trades                                       9035
# Total Closed Trades                                8985
# Total Open Trades                                    50
# Open Trade PnL                                      0.0
# Win Rate [%]                                  57.429048
# Best Trade [%]                               475.399758
# Worst Trade [%]                              -49.999998
# Avg Winning Trade [%]                           3.32419
# Avg Losing Trade [%]                            -2.3871
# Avg Winning Trade Duration    3 days 16:03:04.186046511
# Avg Losing Trade Duration     3 days 01:49:15.729984301
# Profit Factor                                  1.825864
# Expectancy                                   184.412536
# Sharpe Ratio                                   0.843983
# Calmar Ratio                                   1.172447
# Omega Ratio                                    1.265292
# Sortino Ratio                                   2.67749
# Name: group, dtype: object
