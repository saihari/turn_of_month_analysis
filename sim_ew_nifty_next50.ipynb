# %% [markdown]
# # Simulation of Turn of Month Strategy Based on Nifty Next 50 Equal Weight Portfolio

# %%
import vectorbt as vbt
import pandas as pd
import numpy as np
from numba import njit
from vectorbt.portfolio import nb
from vectorbt.portfolio.enums import Direction, NoOrder, SizeType


vbt.settings.portfolio["size_granularity"] = 1

# %%
# Reading the Data

base_path = "./data/simulation_input/niftynext50/"
documentation_path = "./documentation/niftynext50_ew_"

TurnOfMonthEntry = pd.read_csv(base_path + "master_TurnOfMonthEntry.csv")
TurnOfMonthExits = pd.read_csv(base_path + "master_TurnOfMonthExits.csv")
open_price = pd.read_csv(base_path + "master_open_price.csv")
close_price = pd.read_csv(base_path + "master_close_price.csv")

# %% [markdown]
# Set the index as Date and ensure that the entries and exits, are of data type bool and all the dates are of datetime64[ns, UTC+05:30].

# %%
TurnOfMonthEntry.Date = pd.to_datetime(TurnOfMonthEntry.loc[:, "Date"])
TurnOfMonthExits.Date = pd.to_datetime(TurnOfMonthExits.loc[:, "Date"])
open_price.Date = pd.to_datetime(open_price.loc[:, "Date"])
close_price.Date = pd.to_datetime(close_price.loc[:, "Date"])

TurnOfMonthEntry = TurnOfMonthEntry.set_index("Date")
TurnOfMonthExits = TurnOfMonthExits.set_index("Date")
open_price = open_price.set_index("Date")
close_price = close_price.set_index("Date")

for symbol in TurnOfMonthEntry.columns:
    TurnOfMonthEntry[symbol] = TurnOfMonthEntry[symbol].astype(bool)



for symbol in TurnOfMonthExits.columns:
    TurnOfMonthExits[symbol] = TurnOfMonthExits[symbol].astype(bool)

# %% [markdown]
# ## Simulation logic:
#
#     Buy at open on the last trading day of the month.
#     Sell at close on the third trading day of the next month.
#
# Since it is an equal weight simulation and there are 50 companies on the index at any given point of time.
#
# The weight of each company in the portfolio would be 2%.
#
# Also, initial cash is 5,00,000 INR.

# %%
@njit
def order_func_nb(c, entries, exits, size, open_price):

    # Select info related to this order
    entry_now = nb.get_elem_nb(c, entries)
    exit_now = nb.get_elem_nb(c, exits)
    size_now = nb.get_elem_nb(c, size)
    close_price = nb.get_elem_nb(c, c.close)
    open_price = nb.get_elem_nb(c, open_price)

    if entry_now:
        if c.position_now == 0:

            return nb.order_nb(
                size=size_now,
                price=open_price,
                direction=Direction.LongOnly,
                size_type=SizeType.TargetPercent,
                size_granularity= 1,
                min_size=1,
            )

    elif exit_now:
        if c.position_now > 0:
            return nb.order_nb(
                size=-c.position_now,
                price=close_price,
                direction=Direction.LongOnly,
                size_type=SizeType.TargetPercent,
                size_granularity=1,
                min_size=1,
            )

    return NoOrder


def simulate(open_price, close_price, entries, exits, size=0.02, group_by = False, cash_sharing = False, init_cash = 10000):

    return vbt.Portfolio.from_order_func(
        close_price,
        order_func_nb,
        vbt.Rep("entries"),
        vbt.Rep("exits"),
        vbt.Rep("size"),
        vbt.Rep("open_price"),
        init_cash=init_cash,
        cash_sharing=cash_sharing,
        group_by=group_by,
        broadcast_named_args=dict(  # broadcast against each other
            entries=entries, exits=exits, size=size, open_price=open_price
        ),
    )

# %% [markdown]
# ## Simulation

# %%
pf = simulate(
    open_price=open_price,
    close_price=close_price,
    entries=TurnOfMonthEntry[open_price.columns],
    exits=TurnOfMonthExits[open_price.columns],
    size=0.02,
    group_by=True,
    cash_sharing=True,
    init_cash=500000,
)

# %%
print("Total Returns: ", str(pf.total_return() * 100) + "%")
print("Total Annualized Return: ", str(pf.annualized_return(freq="d") * 100) + "%")
print("Total Annualized Volatility: ", str(pf.annualized_volatility(freq="d") * 100) + "%")
# Out:
# Total Returns:  1130.047758961136%
# Total Annualized Return:  27.5037475914337%
# Total Annualized Volatility:  11.24340866148049%

# %% [markdown]
# Monthly Returns

# %%
pf.qs.plot_monthly_heatmap()

# %% [markdown]
# Yearly Returns

# %%
temp = pd.DataFrame(pf.daily_returns()).reset_index()
temp.loc[:,"Year"] = temp.Date.dt.year
temp.fillna(0, inplace=True)
temp.groupby(by="Year").group.sum() * 100
# Out:
# c:\Users\saiha\anaconda3\envs\qfin\lib\site-packages\vectorbt\generic\accessors.py:578: FutureWarning: The 'axis' keyword in Series.resample is deprecated and will be removed in a future version.
#   resampled = self.obj.resample(freq, axis=0, **kwargs)
# Year
# 2009    21.695881
# 2010    28.077396
# 2011    -1.551183
# 2012    23.184547
# 2013    13.219317
# 2014    21.729754
# 2015    18.588752
# 2016    13.158531
# 2017    21.271601
# 2018    -6.487389
# 2019    -1.071591
# 2020    20.216568
# 2021    33.328282
# 2022    17.375150
# 2023    24.373130
# 2024    10.463731
# Name: group, dtype: float64

# %%
pf.plot_value().write_image(engine="orca", file= documentation_path + "value.png")
pf.plot_value()
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '97e21b41-e03e-44ef-9a07-f58e480af361',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([500000., 500000., 500000., ..., 500000., 500000., 500000.])},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(0, 128, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '57cd78de-0884-4def-a854-04e5dfeea8b0',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 500000.        ,  500000.        ,  500000.        , ...,
#                           6150238.79480569, 6150238.79480569, 6150238.79480569])},
#              {'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8bd428d0-2e2b-44a3-b424-d6e451c4b228',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([500000., 500000., 500000., ..., 500000., 500000., 500000.])},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'c2a7a19a-183b-4ef4-9784-8c0affc54ba6',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([500000., 500000., 500000., ..., 500000., 500000., 500000.])},
#              {'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '9bf38476-0183-4dc2-afa9-516ce36933f6',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 500000.        ,  500000.        ,  500000.        , ...,
#                           6150238.79480569, 6150238.79480569, 6150238.79480569])},
#              {'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '9190ea19-bf9d-40d1-b39e-533e21d94ed1',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([500000., 500000., 500000., ..., 500000., 500000., 500000.])}],
#     'layout': {'height': 350,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.02,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 500000.0,
#                            'y1': 500000.0,
#                            'yref': 'y'}],
#                'template': '...',
#                'width': 700}
# })

# %%
pf.plot_drawdowns().write_image(engine="orca", file=documentation_path + "drawdowns.png")
pf.plot_drawdowns()
# Out:
# FigureWidget({
#     'data': [{'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e09bdbf8-7053-4a8c-bff3-45156ddd46ea',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 500000.        ,  500000.        ,  500000.        , ...,
#                           6150238.79480569, 6150238.79480569, 6150238.79480569])},
#              {'customdata': array([[ 39],
#                                    [111],
#                                    [138],
#                                    [170],
#                                    [209]]),
#               'hovertemplate': 'Drawdown Id: %{customdata[0]}<br>Peak Timestamp: %{x}<br>Peak Value: %{y}',
#               'marker': {'color': '#4285F4',
#                          'line': {'color': 'rgb(11,84,205)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': 'Peak',
#               'type': 'scatter',
#               'uid': '60ebeb78-0d76-43ba-9ab8-061aa8a9eed3',
#               'x': array([datetime.datetime(2011, 4, 27, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2015, 6, 3, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2016, 11, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2018, 1, 24, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2022, 4, 11, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 857648.61894696, 1618301.24864738, 2007197.88806641, 2428694.39095433,
#                           4003869.49410217])},
#              {'customdata': array([['39', '-0.08941240588705991', '145'],
#                                    ['111', '-0.06234895484858275', '7'],
#                                    ['138', '-0.05325371062371646', '39'],
#                                    ['170', '-0.20619463783706402', '528'],
#                                    ['209', '-0.0691435860191454', '30']], dtype=object),
#               'hovertemplate': ('Drawdown Id: %{customdata[0]}<' ... '<br>Duration: %{customdata[2]}'),
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': 'Valley',
#               'type': 'scatter',
#               'uid': '04bc3c90-4ff3-40bb-8a98-f3e67979b55d',
#               'x': array([datetime.datetime(2011, 11, 28, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2015, 6, 12, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2016, 12, 27, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2020, 3, 25, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2022, 5, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 780964.19252119, 1517401.85716406, 1900307.15257079, 1927910.6305946 ,
#                           3727027.59932728])},
#              {'customdata': array([['39', '0.10346799700092099', '46'],
#                                    ['111', '0.06807355033270841', '36'],
#                                    ['138', '0.059345595867825694', '21'],
#                                    ['170', '0.26072782376806813', '161'],
#                                    ['209', '0.07449084133775118', '53']], dtype=object),
#               'hovertemplate': ('Drawdown Id: %{customdata[0]}<' ... '<br>Duration: %{customdata[2]}'),
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': 'Recovery/Peak',
#               'type': 'scatter',
#               'uid': 'e028f79d-fc74-4073-a60a-739090bb2c41',
#               'x': array([datetime.datetime(2012, 2, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2015, 8, 3, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2017, 1, 25, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2020, 11, 17, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2022, 8, 10, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([ 861768.9932508 , 1620696.78886266, 2013082.01287199, 2430570.57372885,
#                           4004657.02089019])}],
#     'layout': {'height': 350,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.02,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2011-04-27 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2011-11-28 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2015-06-03 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2015-06-12 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2016-11-01 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2016-12-27 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2018-01-24 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2020-03-25 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2022-04-11 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2022-05-26 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2011-11-28 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2012-02-02 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2015-06-12 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2015-08-03 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2016-12-27 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2017-01-25 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2020-03-25 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2020-11-17 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2022-05-26 00:00:00+0530', tz='UTC+05:30'),
#                            'x1': Timestamp('2022-08-10 00:00:00+0530', tz='UTC+05:30'),
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'paper'}],
#                'template': '...',
#                'width': 700}
# })

# %%
pf.plot_underwater().write_image(engine="orca", file=documentation_path + "underwater.png")
pf.plot_underwater()
# Out:
# FigureWidget({
#     'data': [{'fill': 'tozeroy',
#               'fillcolor': 'rgba(220,57,18,0.3000)',
#               'line': {'color': '#dc3912'},
#               'name': 'Drawdown',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '7d5b03ac-e830-497a-9b04-1ae675c30203',
#               'x': array([datetime.datetime(2009, 1, 1, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 2, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2009, 1, 5, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           ...,
#                           datetime.datetime(2024, 4, 26, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 29, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))),
#                           datetime.datetime(2024, 4, 30, 0, 0, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800)))],
#                          dtype=object),
#               'y': array([0., 0., 0., ..., 0., 0., 0.])}],
#     'layout': {'height': 350,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.02,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y'}],
#                'template': '...',
#                'width': 700,
#                'yaxis': {'tickformat': '%'}}
# })

# %% [markdown]
# Return Stats

# %%
pf.returns_stats(settings=dict(freq="d", risk_free=0.000192))
# Out:
# c:\Users\saiha\anaconda3\envs\qfin\lib\site-packages\vectorbt\returns\accessors.py:902: UserWarning:
#
# Changing the frequency will create a copy of this object. Consider setting it upon object creation to re-use existing cache.
# Start                        2009-01-01 00:00:00+05:30
# End                          2024-04-30 00:00:00+05:30
# Period                              3770 days 00:00:00
# Total Return [%]                           1130.047759
# Benchmark Return [%]                       3020.021607
# Annualized Return [%]                        27.503748
# Annualized Volatility [%]                    11.243409
# Max Drawdown [%]                             20.619464
# Max Drawdown Duration                688 days 00:00:00
# Sharpe Ratio                                  1.594658
# Calmar Ratio                                  1.333873
# Omega Ratio                                   1.333512
# Sortino Ratio                                 3.483157
# Skew                                         -0.045257
# Kurtosis                                     11.863662
# Tail Ratio                                    1.504693
# Common Sense Ratio                            1.918539
# Value at Risk                                -0.006513
# Alpha                                         0.096836
# Beta                                          0.298852
# Name: group, dtype: object

# %%
pf.stats(settings=dict(freq="d", risk_free=0.000192))
# Out:
# c:\Users\saiha\anaconda3\envs\qfin\lib\site-packages\vectorbt\generic\stats_builder.py:262: UserWarning:
#
# Changing the frequency will create a copy of this object. Consider setting it upon object creation to re-use existing cache.
# Start                         2009-01-01 00:00:00+05:30
# End                           2024-04-30 00:00:00+05:30
# Period                               3770 days 00:00:00
# Start Value                                    500000.0
# End Value                                6150238.794806
# Total Return [%]                            1130.047759
# Benchmark Return [%]                        3020.021607
# Max Gross Exposure [%]                        99.999988
# Total Fees Paid                                     0.0
# Max Drawdown [%]                              20.619464
# Max Drawdown Duration                 688 days 00:00:00
# Total Trades                                       7673
# Total Closed Trades                                7623
# Total Open Trades                                    50
# Open Trade PnL                                      0.0
# Win Rate [%]                                  62.337662
# Best Trade [%]                               798.689361
# Worst Trade [%]                              -89.089513
# Avg Winning Trade [%]                          4.936876
# Avg Losing Trade [%]                          -2.838651
# Avg Winning Trade Duration    8 days 11:32:25.454545454
# Avg Losing Trade Duration     6 days 04:53:37.877094972
# Profit Factor                                  3.066339
# Expectancy                                   740.332612
# Sharpe Ratio                                   1.594658
# Calmar Ratio                                   1.333873
# Omega Ratio                                    1.333512
# Sortino Ratio                                  3.483157
# Name: group, dtype: object
